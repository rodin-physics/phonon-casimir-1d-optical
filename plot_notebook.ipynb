# %%
using PGFPlotsX
using Plots
using LaTeXStrings
using DelimitedFiles
include("src/general.jl")
# Out:
# 5-element Array{RGB{Float64},1} with eltype RGB{Float64}:
#  RGB{Float64}(0.8431372549019608,0.2627450980392157,0.32941176470588235)
#  RGB{Float64}(0.41568627450980394,0.6980392156862745,0.2784313725490196)
#  RGB{Float64}(0.39215686274509803,0.396078431372549,0.8549019607843137)
#  RGB{Float64}(0.6627450980392157,0.34901960784313724,0.788235294117647)
#  RGB{Float64}(0.8196078431372549,0.5294117647058824,0.1803921568627451)

# %% [markdown]
# ## Monoatomic Supermassive Limit

# %%
QFT_M_T = readdlm("mono_results/F_I_Mono_M_1e8_QFT_T0p02.dat")
QFT_W_T = readdlm("mono_results/F_I_Mono_W_1e4_QFT_T0p02.dat")

QFT_M = readdlm("mono_results/F_I_Mono_M_1e8_QFT_T0.csv", ',')
QFT_W = readdlm("mono_results/F_I_Mono_W_1e4_QFT_T0.csv", ',')

using DelimitedFiles
using PGFPlotsX
using Plots
using LaTeXStrings

pgfplotsx()
plot(
    xaxis = (L"$\ln\, d$", font(14, "Serif")),
    yaxis = (L"$\ln \left(F_I/F_I^1\right) $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
    yticks = -10:5:0,
)

plot!(log.(1:length(QFT_M)), log.(QFT_M ./ QFT_M[1]), label = false, color = colors[1])
scatter!(log.(1:length(QFT_W)), log.(abs.(QFT_W ./ QFT_W[1])), label = "T = 0", color = colors[1])
plot!(log.(1:length(QFT_M)), log.(QFT_M_T ./ QFT_M_T[1]), label = false, color = colors[2])
scatter!(log.(1:length(QFT_W)), log.(abs.(QFT_W_T ./ QFT_W_T[1])), label = "T = 0.02 Ω", color = colors[2])

plot!(
    log.(1:length(QFT_M)),
    log.(1 ./ (1:length(QFT_M))),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)

# savefig("mono_figs/supermassivelimit.pdf")

# %% [markdown]
# ## Plot monoatomic mass configuration

# %%
ED = readdlm("mono_results/F_I_Exact_result_mono_mixed_T0p02_0.10.1.dat")
QFT_1 = readdlm("mono_results/Archive/F_I_QFT_result_mono_mass_T0p02_0.1.dat")
ED_1 = readdlm("mono_results/Archive/F_I_Exact_result_mono_mass_T0p02_0.1.dat")
QFT_2 = readdlm("mono_results/Archive/F_I_QFT_result_mono_mass_T0p02_0.5.dat")
ED_2 = readdlm("mono_results/Archive/F_I_Exact_result_mono_mass_T0p02_0.5.dat")
QFT_3 = readdlm("mono_results/Archive/F_I_QFT_result_mono_mass_T0p02_5.0.dat")
ED_3 = readdlm("mono_results/Archive/F_I_Exact_result_mono_mass_T0p02_5.0.dat")
QFT_4 = readdlm("mono_results/Archive/F_I_QFT_result_mono_mass_T0p02_50.0.dat")
ED_4 = readdlm("mono_results/Archive/F_I_Exact_result_mono_mass_T0p02_50.0.dat")

pgfplotsx()
plot(
    xaxis = (L"$\ln\, d$", font(14, "Serif")),
    yaxis = (L"$\ln \left(F_I/F_I^1\right) $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
    yticks = -10:5:0,
)

plot!(log.(1:length(ED_1)), log.(ED_1 ./ ED_1[1]), label = false, color = colors[1])
scatter!(log.(1:length(QFT_1)), log.(abs.(QFT_1 ./ QFT_1[1])), label = "M = 0.1", color = colors[1])
plot!(log.(1:length(ED_2)), log.(ED_2 ./ ED_2[1]), label = false, color = colors[2])
scatter!(log.(1:length(QFT_2)), log.(abs.(QFT_2 ./ QFT_2[1])), label = "M = 0.5", color = colors[2])
plot!(log.(1:length(ED_3)), log.(ED_3 ./ ED_3[1]), label = false, color = colors[3])
scatter!(log.(1:length(QFT_3)), log.(abs.(QFT_3 ./ QFT_3[1])), label = "M = 5.0", color = colors[3])
plot!(log.(1:length(ED_4)), log.(ED_4 ./ ED_4[1]), label = false, color = colors[4])
scatter!(log.(1:length(QFT_4)), log.(abs.(QFT_4 ./ QFT_4[1])), label = "M = 50.0", color = colors[4])


plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED))),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)
plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED)) .^ 3),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)
annotate!(2.9, - 0.6, text("(b)", 18))


# savefig("monofigs/mono_mass_finite_T.pdf")

# %%
log_FIs = readdlm( "mono_results/F_I_QFT_mass_limit.csv", ',')
log_FIs_exact = readdlm( "mono_results/F_I_ED_mass_limit.csv", ',')

ED = log_FIs_exact[1:20]

QFT_1 = log_FIs[1:20]
ED_1 = log_FIs_exact[1:20]
QFT_2 = log_FIs[21:40]
ED_2 = log_FIs_exact[21:40]
QFT_3 = log_FIs[41:60]
ED_3 = log_FIs_exact[41:60]
QFT_4 = log_FIs[61:80]
ED_4 = log_FIs_exact[61:80]

using DelimitedFiles
using PGFPlotsX
using Plots
using LaTeXStrings

pgfplotsx()
plot(
    xaxis = (L"$\ln\, d$", font(14, "Serif")),
    yaxis = (L"$\ln \left(F_I/F_I^1\right) $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
    yticks = -10:5:0,
#     ylims = (-5.5, 0)
)

plot!(log.(1:length(ED_1)), ED_1, label = false, color = colors[1])
scatter!(log.(1:length(QFT_1)), QFT_1, label = "M = 0.1", color = colors[1])
plot!(log.(1:length(ED_2)), ED_2, label = false, color = colors[2])
scatter!(log.(1:length(QFT_2)), QFT_2, label = "M = 0.5", color = colors[2])
plot!(log.(1:length(ED_3)), ED_3, label = false, color = colors[3])
scatter!(log.(1:length(QFT_3)), QFT_3, label = "M = 5.0", color = colors[3])
plot!(log.(1:length(ED_4)), ED_4, label = false, color = colors[4])
scatter!(log.(1:length(QFT_4)), QFT_4, label = "M = 50.0", color = colors[4])


plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED))),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)

annotate!(2.9, - 0.6, text("(a)", 18))

# savefig("mono_figs/mass_limit_log_plot.pdf")

# %%
log_FIs = readdlm( "mono_results/F_I_QFT_mass_limit.csv", ',')
log_FIs_exact = readdlm( "mono_results/F_I_ED_mass_limit.csv", ',')

ED = log_FIs_exact[1:20]

QFT_1 = log_FIs[1:20]
ED_1 = log_FIs_exact[1:20]
QFT_2 = log_FIs[21:40]
ED_2 = log_FIs_exact[21:40]
QFT_3 = log_FIs[41:60]
ED_3 = log_FIs_exact[41:60]
QFT_4 = log_FIs[61:80]
ED_4 = log_FIs_exact[61:80]

using DelimitedFiles
using PGFPlotsX
using Plots
using LaTeXStrings

pgfplotsx()
plot(
    xaxis = (L"$\ln\, d$", font(14, "Serif")),
    yaxis = (L"$\ln \left(F_I/F_I^1\right) $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
    yticks = -10:5:0,
)

plot!(log.(1:length(ED_1)), ED_1, label = false, color = colors[1])
scatter!(log.(1:length(QFT_1)), QFT_1, label = "M = 0.1", color = colors[1])
plot!(log.(1:length(ED_2)), ED_2, label = false, color = colors[2])
scatter!(log.(1:length(QFT_2)), QFT_2, label = "M = 0.5", color = colors[2])
plot!(log.(1:length(ED_3)), ED_3, label = false, color = colors[3])
scatter!(log.(1:length(QFT_3)), QFT_3, label = "M = 5.0", color = colors[3])
plot!(log.(1:length(ED_4)), ED_4, label = false, color = colors[4])
scatter!(log.(1:length(QFT_4)), QFT_4, label = "M = 50.0", color = colors[4])


plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED))),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)
plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED)) .^ 3),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)

annotate!(2.9, - 0.6, text("(a)", 18))

savefig("mono_figs/mass_limit_log_plot.pdf")

# %% [markdown]
# ## plot mono well configs

# %%
ED = readdlm("mono_results/F_I_Exact_result_mono_mixed_T0p02_0.10.1.dat")
QFT_1 = readdlm("mono_results/Archive/F_I_QFT_result_mono_well_T0p02_0.1.dat")
ED_1 = readdlm("mono_results/Archive/F_I_Exact_result_mono_well_T0p02_0.1.dat")
QFT_2 = readdlm("mono_results/Archive/F_I_QFT_result_mono_well_T0p02_0.2.dat")
ED_2 = readdlm("mono_results/Archive/F_I_Exact_result_mono_well_T0p02_0.2.dat")
QFT_3 = readdlm("mono_results/Archive/F_I_QFT_result_mono_well_T0p02_0.5.dat")
ED_3 = readdlm("mono_results/Archive/F_I_Exact_result_mono_well_T0p02_0.5.dat")
QFT_4 = readdlm("mono_results/Archive/F_I_QFT_result_mono_well_T0p02_5.0.dat")
ED_4 = readdlm("mono_results/Archive/F_I_Exact_result_mono_well_T0p02_5.0.dat")

using DelimitedFiles
using PGFPlotsX
using Plots
using LaTeXStrings

pgfplotsx()
plot(
    xaxis = (L"$\ln\, d$", font(14, "Serif")),
    yaxis = (L"$\ln \left(F_I/F_I^1\right) $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
    yticks = -10:5:0,
#     ylims = (-10.5,0)
)
# plot!(log.(1:length(ED)), log.(ED ./ ED[1]))
# scatter!(log.(1:length(QFT)), log.(QFT ./ QFT[1]))

# plot!(log.(1:length(ED_1)), log.(ED_1 ./ ED_1[1]), label = false, color = colors[1])
scatter!(log.(1:length(QFT_1)), log.(abs.(QFT_1 ./ QFT_1[1])), label = "Δ = 0.1", color = colors[1])
# plot!(log.(1:length(ED_2)), log.(ED_2 ./ ED_2[1]), label = false, color = colors[2])
scatter!(log.(1:length(QFT_2)), log.(abs.(QFT_2 ./ QFT_2[1])), label = "Δ = 0.2", color = colors[2])
# plot!(log.(1:length(ED_3)), log.(ED_3 ./ ED_3[1]), label = false, color = colors[3])
scatter!(log.(1:length(QFT_3)), log.(abs.(QFT_3 ./ QFT_3[1])), label = "Δ = 0.5", color = colors[3])
# plot!(log.(1:length(ED_4)), log.(ED_4 ./ ED_4[1]), label = false, color = colors[4])
scatter!(log.(1:length(QFT_4)), log.(abs.(QFT_4 ./ QFT_4[1])), label = "Δ = 5.0", color = colors[4])


plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED))),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)

annotate!(2.9, - 0.4, text("(b)", 18))

# savefig("mono_figs/mono_well_finite_T.pdf")

# %%
pgfplotsx()
plot(
    xaxis = (L"$d$", font(14, "Serif")),
    yaxis = (L"$\ln \left(F_I/F_I^1\right) $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
    yticks = -10:5:0,
#     ylims = (-10.5,0)
)
# plot!(log.(1:length(ED)), log.(ED ./ ED[1]))
# scatter!(log.(1:length(QFT)), log.(QFT ./ QFT[1]))

# plot!(log.(1:length(ED_1)), log.(ED_1 ./ ED_1[1]), label = false, color = colors[1])
scatter!(1:length(QFT_1), log.(abs.(QFT_1 ./ QFT_1[1])), label = "Δ = 0.1", color = colors[1])
# plot!(log.(1:length(ED_2)), log.(ED_2 ./ ED_2[1]), label = false, color = colors[2])
scatter!(1:length(QFT_2), log.(abs.(QFT_2 ./ QFT_2[1])), label = "Δ = 0.2", color = colors[2])
# plot!(log.(1:length(ED_3)), log.(ED_3 ./ ED_3[1]), label = false, color = colors[3])
scatter!(1:length(QFT_3), log.(abs.(QFT_3 ./ QFT_3[1])), label = "Δ = 0.5", color = colors[3])
# plot!(log.(1:length(ED_4)), log.(ED_4 ./ ED_4[1]), label = false, color = colors[4])
scatter!(1:length(QFT_4), log.(abs.(QFT_4 ./ QFT_4[1])), label = "Δ = 5.0", color = colors[4])

# %%
log_FIs = readdlm( "mono_results/F_I_QFT_harmonic_limit.csv",  ',')
log_FIs_exact = readdlm( "mono_results/F_I_ED_harmonic_limit.csv", ',')

ED = log_FIs_exact[1:20]

QFT_1 = log_FIs[1:20]
ED_1 = log_FIs_exact[1:20]
QFT_2 = log_FIs[21:40]
ED_2 = log_FIs_exact[21:40]
QFT_3 = log_FIs[41:60]
ED_3 = log_FIs_exact[41:60]
QFT_4 = log_FIs[61:80]
ED_4 = log_FIs_exact[61:80]

using DelimitedFiles
using PGFPlotsX
using Plots
using LaTeXStrings

pgfplotsx()
plot(
    xaxis = (L"$\ln\, d$", font(14, "Serif")),
    yaxis = (L"$\ln \left(F_I/F_I^1\right) $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
    yticks = -10:5:0,
    ylims = (-5.5, 0)
)

plot!(log.(1:length(ED_1)), ED_1, label = false, color = colors[1])
scatter!(log.(1:length(QFT_1)), QFT_1, label = "Δ = 0.1", color = colors[1])
plot!(log.(1:length(ED_2)), ED_2, label = false, color = colors[2])
scatter!(log.(1:length(QFT_2)), QFT_2, label = "Δ = 0.2", color = colors[2])
plot!(log.(1:length(ED_3)), ED_3, label = false, color = colors[3])
scatter!(log.(1:length(QFT_3)), QFT_3, label = "Δ = 0.5", color = colors[3])
plot!(log.(1:length(ED_4)), ED_4, label = false, color = colors[4])
scatter!(log.(1:length(QFT_4)), QFT_4, label = "Δ = 5.0", color = colors[4])


plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED))),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)

annotate!(2.9, - 0.3, text("(a)", 18))
# savefig("mono_figs/harmonic_limit_log_plot.pdf")

# %% [markdown]
# ## plot mixed configs

# %%
ED = readdlm("mono_results/F_I_Exact_result_mono_mixed_T0p02_0.10.1.dat")

QFT_1 = readdlm("mono_results/F_I_QFT_result_mono_well_T0p02_0.1.dat")
ED_1 = readdlm("mono_results/F_I_Exact_result_mono_well_T0p02_0.1.dat")
QFT_2 = readdlm("mono_results/F_I_QFT_result_mono_mixed_T0p02_0.10.1.dat")
ED_2 = readdlm("mono_results/F_I_Exact_result_mono_mixed_T0p02_0.10.1.dat")
QFT_3 = readdlm("mono_results/F_I_QFT_result_mono_mass_T0p02_0.1.dat")
ED_3 = readdlm("mono_results/F_I_Exact_result_mono_mass_T0p02_0.1.dat")



# QFT = QFT .+ F_I_1_T0 .- F_I_1

using DelimitedFiles
using PGFPlotsX
using Plots
using LaTeXStrings

pgfplotsx()
plot(
    xaxis = (L"$\ln\, d$", font(14, "Serif")),
    yaxis = (L"$\ln \left(F_I/F_I^1\right) $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
    yticks = -10:5:0,
)
# plot!(log.(1:length(ED)), log.(ED ./ ED[1]))
# scatter!(log.(1:length(QFT)), log.(QFT ./ QFT[1]))

# plot!(log.(1:length(ED_1)), log.(ED_1 ./ ED_1[1]), label = false, color = colors[1])
scatter!(log.(1:length(QFT_1)), log.(abs.(QFT_1 ./ QFT_1[1])), label = "Δ-Δ", color = colors[1])
# plot!(log.(1:length(ED_2)), log.(ED_2 ./ ED_2[1]), label = false, color = colors[2])
scatter!(log.(1:length(QFT_2)), log.(abs.(QFT_2 ./ QFT_2[1])), label = "M-Δ", color = colors[2])
# plot!(log.(1:length(ED_3)), log.(ED_3 ./ ED_3[1]), label = false, color = colors[3])
scatter!(log.(1:length(QFT_3)), log.(abs.(QFT_3 ./ QFT_3[1])), label = "M-M", color = colors[3])


plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED))),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)
plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED)) .^ 3),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)

annotate!(2.9, - 0.6, text("(b)", 18))

# savefig("monofigs/mono_mixed_finite_T_0p1.pdf")

# %%
ED = readdlm("mono_results/F_I_Exact_result_mono_mixed_T0p02_10.010.0.dat")

QFT_1 = readdlm("mono_results/F_I_QFT_result_mono_well_T0p02_10.0.dat")
ED_1 = readdlm("mono_results/F_I_Exact_result_mono_well_T0p02_10.0.dat")
QFT_2 = readdlm("mono_results/F_I_QFT_result_mono_mixed_T0p02_10.010.0.dat")
ED_2 = readdlm("mono_results/F_I_Exact_result_mono_mixed_T0p02_10.010.0.dat")
QFT_3 = readdlm("mono_results/F_I_QFT_result_mono_mass_T0p02_10.0.dat")
ED_3 = readdlm("mono_results/F_I_Exact_result_mono_mass_T0p02_10.0.dat")

using DelimitedFiles
using PGFPlotsX
using Plots
using LaTeXStrings

pgfplotsx()
plot(
    xaxis = (L"$\ln\, d$", font(14, "Serif")),
    yaxis = (L"$\ln \left(F_I/F_I^1\right) $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
    yticks = -10:5:0,
    ylims = (-10.5, 0)
)

# plot!(log.(1:length(ED_1)), log.(ED_1 ./ ED_1[1]), label = false, color = colors[1])
scatter!(log.(1:length(QFT_1)), log.(abs.(QFT_1 ./ QFT_1[1])), label = "Δ-Δ", color = colors[1])
# plot!(log.(1:length(ED_2)), log.(ED_2 ./ ED_2[1]), label = false, color = colors[2])
scatter!(log.(1:length(QFT_2)), log.(abs.(QFT_2 ./ QFT_2[1])), label = "M-Δ", color = colors[2])
# plot!(log.(1:length(ED_3)), log.(ED_3 ./ ED_3[1]), label = false, color = colors[3])
scatter!(log.(1:length(QFT_3)), log.(abs.(QFT_3 ./ QFT_3[1])), label = "M-M", color = colors[3])

plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED))),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)
plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED)) .^ 3),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)

annotate!(2.9, - 0.5, text("(a)", 18))

savefig("monofigs/mono_mixed_finite_T_10.pdf")

# %%
log_range_of_F_ΔΔ = readdlm( "mono_results/F_I_QFT_dd_heavy_limit.csv", ',')
log_range_of_F_exact_ΔΔ = readdlm( "mono_results/F_I_ED_dd_heavy_limit.csv", ',')
log_range_of_F = readdlm( "mono_results/F_I_QFT_md_heavy_limit.csv", ',')
log_range_of_F_exact = readdlm( "mono_results/F_I_ED_md_heavy_limit.csv",  ',')
log_range_of_F_MM = readdlm( "mono_results/F_I_QFT_mm_heavy_limit.csv",  ',')
log_range_of_F_exact_MM = readdlm( "mono_results/F_I_ED_mm_heavy_limit.csv",',')

pgfplotsx()
plot(
    xaxis = (L"$\ln\, d$", font(14, "Serif")),
    yaxis = (L"$\ln \left(F_I/F_I^1\right) $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
    yticks = -10:5:0,
    ylims = (-10.5, 0)
)

log_t = map(t -> log(t), 1:20);

scatter!(log_t, log_range_of_F_ΔΔ, label = "Δ-Δ", color = colors[1])
plot!(log_t, log_range_of_F_exact_ΔΔ, label = false, color = colors[1])
scatter!(log_t, log_range_of_F, label = "M-Δ", color = colors[2])
plot!(log_t, log_range_of_F_exact, label = false, color = colors[2])
scatter!(log_t, log_range_of_F_MM, label = "M-M", color = colors[3])
plot!(log_t, log_range_of_F_exact_MM, label = false, color = colors[3])

# scatter!(log_t, log_FIs[21:40], label = "Δ = 2.0")
# scatter!(log_t, log_FIs[41:60], label = "Δ = 5.0")
# scatter!(log_t, log_FIs[61:80], label = "Δ = 50.0")
plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED))),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)
plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED)) .^ 3),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)

annotate!(2.9, - 0.5, text("(a)", 18))

# savefig("mono_figs/mass_harm_gg_1_log_plot.pdf")

# %%
log_range_of_F_ΔΔ = readdlm( "mono_results/F_I_QFT_dd_light_limit.csv", ',')
log_range_of_F_exact_ΔΔ = readdlm( "mono_results/F_I_ED_dd_light_limit.csv", ',')
log_range_of_F = readdlm( "mono_results/F_I_QFT_md_light_limit.csv", ',')
log_range_of_F_exact = readdlm( "mono_results/F_I_ED_md_light_limit.csv",  ',')
log_range_of_F_MM = readdlm( "mono_results/F_I_QFT_mm_light_limit.csv",  ',')
log_range_of_F_exact_MM = readdlm( "mono_results/F_I_ED_mm_light_limit.csv",',')

pgfplotsx()
plot(
    xaxis = (L"$\ln\, d$", font(14, "Serif")),
    yaxis = (L"$\ln \left(F_I/F_I^1\right) $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
    yticks = -10:5:0,
#     ylims = (-10.5, 0)
)

log_t = map(t -> log(t), 1:20);

scatter!(log_t, log_range_of_F_ΔΔ, label = "Δ-Δ", color = colors[1])
plot!(log_t, log_range_of_F_exact_ΔΔ, label = false, color = colors[1])
scatter!(log_t, log_range_of_F, label = "M-Δ", color = colors[2])
plot!(log_t, log_range_of_F_exact, label = false, color = colors[2])
scatter!(log_t, log_range_of_F_MM, label = "M-M", color = colors[3])
plot!(log_t, log_range_of_F_exact_MM, label = false, color = colors[3])


plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED))),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)
plot!(
    log.(1:length(ED)),
    log.(1 ./ (1:length(ED)) .^ 3),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)

annotate!(2.9, - 0.6, text("(b)", 18))

# savefig("mono_figs/mass_harm_ll_1_log_plot.pdf")

# %% [markdown]
# ## Diatomic Plots

# %%
pgfplotsx()
plot(
    xaxis = (L"$\ln\, d$", font(14, "Serif")),
    yaxis = (L"$F_I/F_I^1 $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :topright,
    yticks = -1:1:1,
)

nCells = 10
F_I_QFT_result_1 = readdlm( "diatomic_results/F_I_QFT_result_left_heavy_1_3_MM1p8_v2.csv", ',')
F_I_Exact_result_1 = readdlm( "diatomic_results/F_I_ED_result_left_heavy_1_3_MM1p8_v2.csv", ',')
F_I_QFT_result_2 = readdlm( "diatomic_results/F_I_QFT_result_left_light_1_3_MM1p8_v2.csv", ',')
F_I_Exact_result_2 = readdlm( "diatomic_results/F_I_ED_result_left_light_1_3_MM1p8_v2.csv", ',')
scatter!(log.(1:2*nCells), F_I_QFT_result_1[1:20] ./ F_I_QFT_result_1[1], label = "fix heavy", color = colors[1])
plot!(log.(1:2*nCells), F_I_Exact_result_1[1:20] ./ F_I_Exact_result_1[1]  , label = false, color = colors[1])
scatter!(log.(1:2*nCells), F_I_QFT_result_2[1:20] ./ F_I_QFT_result_2[1] , label = "fix light", color = colors[2])
plot!(log.(1:2*nCells), F_I_Exact_result_2[1:20] ./ F_I_Exact_result_2[1], label = false, color = colors[2])

# savefig("diatomic_figs/oscillatingplot.pdf")

# %%
pgfplotsx()
plot(
    xaxis = (L"$\ln\, D$", font(14, "Serif")),
    yaxis = (L"$F_I/F_I^1 $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :topright,
    yticks = -1:1:1,
)

nCells = 10
F_I_QFT_result_1 = readdlm( "diatomic_results/F_I_QFT_result_left_light_1_3_MM1p8_T0p02.csv", ',')
F_I_Exact_result_1 = readdlm( "diatomic_results/F_I_Exact_result_left_light_1_3_MM1p8_T0p02.csv", ',')
F_I_QFT_result_2 = readdlm( "diatomic_results/F_I_QFT_result_left_heavy_1_3_MM1p8_T0p02.csv", ',')
F_I_Exact_result_2 = readdlm( "diatomic_results/F_I_Exact_result_left_heavy_1_3_MM1p8_T0p02.csv", ',')
scatter!(log.(1:2*nCells), F_I_QFT_result_1[1:20] ./ F_I_QFT_result_1[1], label = "Fix Heavy", color = colors[1])
plot!(log.(1:2*nCells), F_I_Exact_result_1[1:20] ./ F_I_Exact_result_1[1]  , label = false, color = colors[1])
scatter!(log.(1:2*nCells), F_I_QFT_result_2[1:20] ./ F_I_QFT_result_2[1] , label = "Fix Light", color = colors[2])
plot!(log.(1:2*nCells), F_I_Exact_result_2[1:20] ./ F_I_Exact_result_2[1], label = false, color = colors[2])

# %%
pgfplotsx()
plot(
    xaxis = (L"$\ln\, d_u$", font(14, "Serif")),
    yaxis = (L"$\ln \left(F_I/F_I^1\right) $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
    yticks = -10:5:0,
)
F_I_QFT_Odd_1 = zeros(10)
F_I_QFT_Odd_2 = zeros(10)
F_I_QFT_Even_1 = zeros(10)
F_I_QFT_Even_2 = zeros(10)
# println(F_I_QFT_Odd)
for ii in 1:length(F_I_QFT_Odd_1)

    F_I_QFT_Odd_1[ii] = F_I_QFT_result_1[2 * ii - 1]
    F_I_QFT_Odd_2[ii] = F_I_QFT_result_2[2 * ii - 1]
    F_I_QFT_Even_1[ii] = F_I_QFT_result_1[2 * ii]
    F_I_QFT_Even_2[ii] = F_I_QFT_result_2[2 * ii]

end

scatter!(log.(1:length(F_I_QFT_Odd_1)), log.(F_I_QFT_Odd_1 ./ F_I_QFT_Odd_1[1]),color = colors[1], label = "heavy-light")
# scatter!(log.(1:length(F_I_QFT_Odd_2)), log.(F_I_QFT_Odd_2 ./ F_I_QFT_Odd_2[1]),color = colors[2], label = "light-light")
scatter!(log.(1:length(F_I_QFT_Even_1)), log.(F_I_QFT_Even_1 ./ F_I_QFT_Even_1[1]), color = colors[2], label = "heavy-heavy")
scatter!(log.(1:length(F_I_QFT_Even_2)), log.(F_I_QFT_Even_2 ./ F_I_QFT_Even_2[1]), color = colors[3], label = "light-light")
log_t = log.(1:length(F_I_QFT_Even_2))
# plot!(log_t, -3 .* log_t, c = :black, label = false, linestyle = :dash)

plot!(
    log.(1:length(F_I_QFT_Odd_1)),
    log.(1 ./ (1:length(F_I_QFT_Odd_1)) .^ 3),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)

annotate!(2.3, - 0.6, text("(a)", 18))

# savefig("diatomic_figs/odd_even_scaling_plot.pdf")

# %%
pgfplotsx()
plot(
    xaxis = (L"$\ln\, d_u$", font(14, "Serif")),
    yaxis = (L"$\ln \left(F_I/F_I^1\right) $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
    yticks = -10:5:0,
)
F_I_QFT_Odd_1 = zeros(10)
F_I_QFT_Odd_2 = zeros(10)
F_I_QFT_Even_1 = zeros(10)
F_I_QFT_Even_2 = zeros(10)
# println(F_I_QFT_Odd)
for ii in 1:length(F_I_QFT_Odd_1)

    F_I_QFT_Odd_1[ii] = F_I_QFT_result_1[2 * ii - 1]
    F_I_QFT_Odd_2[ii] = F_I_QFT_result_2[2 * ii - 1]
    F_I_QFT_Even_1[ii] = F_I_QFT_result_1[2 * ii]
    F_I_QFT_Even_2[ii] = F_I_QFT_result_2[2 * ii]

end

scatter!(log.(1:length(F_I_QFT_Odd_1)), log.(F_I_QFT_Odd_1 ./ F_I_QFT_Odd_1[1]),color = colors[1], label = "heavy-light")
# scatter!(log.(1:length(F_I_QFT_Odd_2)), log.(F_I_QFT_Odd_2 ./ F_I_QFT_Odd_2[1]),color = colors[2], label = "light-light")
scatter!(log.(1:length(F_I_QFT_Even_1)), log.(F_I_QFT_Even_1 ./ F_I_QFT_Even_1[1]), color = colors[2], label = "heavy-heavy")
scatter!(log.(1:length(F_I_QFT_Even_2)), log.(F_I_QFT_Even_2 ./ F_I_QFT_Even_2[1]), color = colors[3], label = "light-light")
log_t = log.(1:length(F_I_QFT_Even_2))
plot!(
    log.(1:length(F_I_QFT_Odd_1)),
    log.(1 ./ (1:length(F_I_QFT_Odd_1)) .^ 3),
    linewidth = 2,
    color = RGB(50 / 255, 50 / 255, 50 / 255),
    line = :dash,
    lab = "",
)

annotate!(2.3, - 0.6, text("(b)", 18))

# savefig("diatomic_figs/odd_even_scaling_plot_T0p02.pdf")

# %% [markdown]
# ## heatmaps

# %%
QFT_data = readdlm("diatomic_results/5x5y_QFT_heatmap_data", ',', Float64, '\n')
Δ_step = 0.1
modF = 10
bound = maximum(abs.(modF .* QFT_data))
println(bound)

fig = heatmap(map(t -> t * Δ_step, 0:size(QFT_data,1) - 1),
    map(t -> t * Δ_step, 0:size(QFT_data,2) - 1), modF .* QFT_data,
    color = :seismic,
    xaxis = (L"$\Delta_R$", font(14, "Serif")),
    yaxis = (L"$\Delta_L$", font(14, "Serif")),
#     xlabel=L"$\Delta_R$", ylabel=L"$\Delta_L$",
    clim = (-bound, bound),
    colorbar = true,
    colorbar_title = L"$F_I\times 10$",
    xtickfont = font(12, "Serif"), ytickfont = font(12, "Serif"),
#     title="Well-Well Interaction at D = 1 on a Monoatomic Chain"
)

annotate!(4.8, 4.8, text("(a)", 18, color = :white))
savefig("mono_figs/monoatomic_well_well_heatmap.pdf")
# savefig(fig, "figures/monoatomic_well_well_heatmap")
# Out:
# 0.7889110955951162

# %%
QFT_data = readdlm("diatomic_results/mass_well_QFT_heatmap_data.csv", ',', Float64, '\n')
Δ_step = 0.1
modF = 10
bound = maximum(abs.(modF .* QFT_data))

fig = heatmap(map(t -> t * Δ_step, 0:size(QFT_data,1) - 1),
    map(t -> t * Δ_step, 0:size(QFT_data,2) - 1), modF .* QFT_data,
    color = :seismic,
    xaxis = (L"$M$", font(14, "Serif")),
    yaxis = (L"$\Delta$", font(14, "Serif")),
#     xlabel=L"$M$", ylabel=L"Δ",
    clim = (-bound, bound),
    colorbar = true,
    colorbar_title = L"$F_I\times 10$",
    xtickfont = font(12, "Serif"), ytickfont = font(12, "Serif"),
#     title="Well-Well Interaction at D = 1 on a Monoatomic Chain"
)

annotate!(4.8, 4.8, text("(b)", 18, color = :white))

savefig("mono_figs/monoatomic_mass_well_heatmap.pdf")

# %% [markdown]
# ## cluster

# %%
range_of_F_M_1 = readdlm("cluster_results/cluster_range_1.dat")
range_of_F_M_2 = readdlm("cluster_results/cluster_range_2.dat")
range_of_F_M_3 = readdlm("cluster_results/cluster_range_3.dat")
range_of_F_M_4 = readdlm("cluster_results/cluster_range_4.dat")

pgfplotsx()
plot(
    xaxis = (L"$ d$", font(14, "Serif")),
    yaxis = (L"$ (F_I - F_I^0) \times 10^4 $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
#     yticks = -10:5:0,
)
# println(F_I_QFT_Odd)

# plot!(log_t, -3 .* log_t, c = :black, label = false, linestyle = :dash)

annotate!(0.2, 4., text("(a)", 18))
maxT = 5
modF = 1e4
plot!(0:maxT, modF .* (range_of_F_M_1[1:maxT + 1] .- range_of_F_M_1[1]), color = colors[1], label = "M = 0.5")
plot!(0:maxT, modF .* (range_of_F_M_2[1:maxT + 1] .- range_of_F_M_2[1]), color = colors[2], label = "M = 0.8")
plot!(0:maxT, modF .* (range_of_F_M_3[1:maxT + 1] .- range_of_F_M_3[1]), color = colors[3], label = "M = 1.5")
plot!(0:maxT, modF .* (range_of_F_M_4[1:maxT + 1] .- range_of_F_M_4[1]), color = colors[4], label = "M = 2.0")

# savefig("cluster_figs/cluster_landscape_T0.pdf")

# %%
pgfplotsx()
plot(
    xaxis = (L"$ D$", font(14, "Serif")),
    yaxis = (L"$ F_I - F_I^0 $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
#     yticks = -10:5:0,
)
# println(F_I_QFT_Odd)

# plot!(log_t, -3 .* log_t, c = :black, label = false, linestyle = :dash)

annotate!(0.17, 0.0023, text("(a)", 18))
maxT = 7

plot!(log.(1:maxT), log.((range_of_F_M_1[2:maxT + 1] .- range_of_F_M_1[1]) ./ (range_of_F_M_1[2] - range_of_F_M_1[1])), color = colors[1], label = "M = 0.5")
plot!(log.(1:maxT), log.((range_of_F_M_2[2:maxT + 1] .- range_of_F_M_2[1]) ./ (range_of_F_M_2[2] - range_of_F_M_2[1])), color = colors[2], label = "M = 0.8")
plot!(log.(1:maxT), log.((range_of_F_M_3[2:maxT + 1] .- range_of_F_M_3[1]) ./ (range_of_F_M_3[2] - range_of_F_M_3[1])), color = colors[3], label = "M = 1.5")
plot!(log.(1:maxT), log.((range_of_F_M_4[2:maxT + 1] .- range_of_F_M_4[1]) ./ (range_of_F_M_4[2] - range_of_F_M_4[1])), color = colors[4], label = "M = 2.0")

# savefig("clusterfigs/cluster_landscape_T0p02.pdf")

# %%
# Out:
# 8×1 Array{Float64,2}:
#  -5.34581465316819e-7
#  -9.984073006674699e-7
#  -3.1953771570947254e-6
#  -1.0946224912322666e-5
#  -3.779622232236157e-5
#  -0.00013139729383243592
#  -0.00046614078427298367
#  -0.0017687984683912306

# %%
range_of_F_M_1
# Out:
# 8×1 Array{Float64,2}:
#  -1.3669129900473198e-5
#  -4.3393766658739175e-5
#   0.00015337770205609003
#   4.51331720162651e-5
#   0.0008167614162279402
#   0.00036149647058592027
#   0.008560165606797676
#   0.002104348887534191

# %%
range_of_F_M_1 = readdlm("cluster_results/cluster_range_1_T0p1.dat")
range_of_F_M_2 = readdlm("cluster_results/cluster_range_2_T0p1.dat")
range_of_F_M_3 = readdlm("cluster_results/cluster_range_3_T0p1.dat")
range_of_F_M_4 = readdlm("cluster_results/cluster_range_4_T0p1.dat")

pgfplotsx()
plot(
    xaxis = (L"$ D$", font(14, "Serif")),
    yaxis = (L"$ (F_I - F_I^0) \times 10^3 $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :topleft,
#     yticks = -10:5:0,
)
# println(F_I_QFT_Odd)

# plot!(log_t, -3 .* log_t, c = :black, label = false, linestyle = :dash)

annotate!(0.17, 0.0023, text("(b)", 18))
maxT = 7
modF = 1e3

plot!(0:maxT, modF .* (range_of_F_M_1 .- range_of_F_M_1[1]), color = colors[1], label = "M = 0.5")
plot!(0:maxT, modF .* (range_of_F_M_2 .- range_of_F_M_2[1]), color = colors[2], label = "M = 0.8")
plot!(0:maxT, modF .* (range_of_F_M_3 .- range_of_F_M_3[1]), color = colors[3], label = "M = 1.5")
plot!(0:maxT, modF .* (range_of_F_M_4 .- range_of_F_M_4[1]), color = colors[4], label = "M = 2.0")

# savefig("cluster_figs/cluster_landscape_T0p02.pdf")

# %%
pgfplotsx()
plot(
    xaxis = (L"$ D$", font(14, "Serif")),
    yaxis = (L"$ F_I - F_I^0 $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
#     yticks = -10:5:0,
)
# println(F_I_QFT_Odd)

# plot!(log_t, -3 .* log_t, c = :black, label = false, linestyle = :dash)

annotate!(0.17, 0.0023, text("(b)", 18))
maxT = 7

plot!(log.(1:maxT), log.((range_of_F_M_1[2:maxT + 1] .- range_of_F_M_1[1]) ./ (range_of_F_M_1[2] - range_of_F_M_1[1])), color = colors[1], label = "M = 0.5")
plot!(log.(1:maxT), log.((range_of_F_M_2[2:maxT + 1] .- range_of_F_M_2[1]) ./ (range_of_F_M_2[2] - range_of_F_M_2[1])), color = colors[2], label = "M = 0.8")
plot!(log.(1:maxT), log.((range_of_F_M_3[2:maxT + 1] .- range_of_F_M_3[1]) ./ (range_of_F_M_3[2] - range_of_F_M_3[1])), color = colors[3], label = "M = 1.5")
plot!(log.(1:maxT), log.((range_of_F_M_4[2:maxT + 1] .- range_of_F_M_4[1]) ./ (range_of_F_M_4[2] - range_of_F_M_4[1])), color = colors[4], label = "M = 2.0")

# savefig("cluster_figs/cluster_landscape_T0p02.pdf")

# %% [markdown]
# ## diatomic clusters

# %%
range_of_F_M_1 = readdlm("cluster_results/di_cluster_range_1.dat")
range_of_F_M_2 = readdlm("cluster_results/di_cluster_range_2.dat")
range_of_F_M_3 = readdlm("cluster_results/di_cluster_range_3.dat")

pgfplotsx()
plot(
    xaxis = (L"$ d$", font(14, "Serif")),
    yaxis = (L"$ (F_I - F_I^0) \times 10^3 $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :bottomleft,
#     yticks = -10:5:0,
)
# println(F_I_QFT_Odd)

# plot!(log_t, -3 .* log_t, c = :black, label = false, linestyle = :dash)

annotate!(0.2, 1.6, text("(b)", 18))
maxT = 5
modF = 1e3

plot!(0:maxT, modF.* (range_of_F_M_1[1:maxT + 1] .- range_of_F_M_1[1]), color = colors[1], label = "M = 0.5")
plot!(0:maxT, modF.* (range_of_F_M_2[1:maxT + 1] .- range_of_F_M_2[1]), color = colors[2], label = "M = 1.8")
plot!(0:maxT, modF.* (range_of_F_M_3[1:maxT + 1] .- range_of_F_M_3[1]), color = colors[3], label = "M = 4.2")
# plot!(0:maxT, range_of_F_M_4 .- range_of_F_M_4[1], color = colors[4], label = "M = 2.0")

# savefig("cluster_figs/di_cluster_landscape_T0.pdf")

# %%
range_of_F_M_1 = readdlm("cluster_results/di_cluster_range_1_T0p1_long.dat")
range_of_F_M_2 = readdlm("cluster_results/di_cluster_range_2_T0p1.dat")
range_of_F_M_3 = readdlm("cluster_results/di_cluster_range_3_T0p1.dat")

pgfplotsx()
plot(
    xaxis = (L"$ D$", font(14, "Serif")),
    yaxis = (L"$ F_I - F_I^0 $", font(14, "Serif")),
    xtickfont = font(12, "Serif"),
    ytickfont = font(12, "Serif"),
    legendfont = font(12, "Serif"),
    legend = :topleft,
#     yticks = -10:5:0,
)
# println(F_I_QFT_Odd)

# plot!(log_t, -3 .* log_t, c = :black, label = false, linestyle = :dash)

# annotate!(4.8, 0.0016, text("(b)", 18))
maxT = 5

plot!(0:maxT, range_of_F_M_1[1:maxT + 1] .- range_of_F_M_1[1], color = colors[1], label = "M = 0.5")
plot!(0:maxT, range_of_F_M_2[1:maxT + 1] .- range_of_F_M_2[1], color = colors[2], label = "M = 1.8")
plot!(0:maxT, range_of_F_M_3[1:maxT + 1] .- range_of_F_M_3[1], color = colors[3], label = "M = 4.2")
# plot!(0:maxT, range_of_F_M_4 .- range_of_F_M_4[1], color = colors[4], label = "M = 2.0")

# savefig("cluster_figs/di_cluster_landscape_T0p1.pdf")
